# %% [markdown]
# ## Uniform Dist

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
values = np.random.uniform(-10,10,10000)
plt.hist(values,100)
plt.show()

# %% [markdown]
# ## Normal

# %%
from scipy.stats import norm
x = np.arange(-3,3,0.001)
x
# Out:
# array([-3.   , -2.999, -2.998, ...,  2.997,  2.998,  2.999])

# %%
plt.plot(x,norm.pdf(x))

# %%
# this time with mu and sigma
mu = 5
sigma =2
values = np.random.normal(mu, sigma, 10000)
plt.hist(values,50)
plt.show()

# %%
from scipy.stats import expon
x = np.arange(0,10,0.001)
plt.plot(x,expon.pdf(x))

# %%
from scipy.stats import poisson
mu = 500
x = np.arange(400,600,5.5)
plt.plot(x,poisson.pmf(x,mu))

# %% [markdown]
# # Percentiles

# %%
np.percentile(values,50)
# Out:
# 5.000788645867269

# %%
np.percentile(values,90)
# Out:
# 7.563384685554853

# %%
np.percentile(values,20)
# Out:
# 3.331029504258143

# %%
np.mean(values)
# Out:
# 4.998712913634331

# %%
np.var(values)
# Out:
# 3.9273829919735457

# %%
import scipy.stats as sp

# %%
sp.skew(values)
# Out:
# -0.0050764357670094375

# %%
sp.kurtosis(values)
# Out:
# -0.025938968986641164

# %%
x = np.arange(-5,5,0.1)
plt.plot(x,norm.pdf(x))
plt.plot(x,norm.pdf(x,1,0.5 ))
plt.show()

# %%
x = np.arange(-5,5,0.1)
plt.plot(x,norm.pdf(x))
plt.plot(x,norm.pdf(x,1,0.5 ))
plt.savefig('someplot.png',format='png')

# %%
pwd
# Out:
# 'C:\\'

# %%
x = np.arange(-5,5,0.1)
axes = plt.axes()
axes.set_xlim([-4,3])
axes.set_ylim([0,2])
axes.set_xticks([-2.1,2])
axes.set_yticks([0,0.5,0.7,2])
axes.grid()
plt.xlabel('Bla Bla shel X')
plt.ylabel('Bla Bla shel Y')
plt.plot(x,norm.pdf(x),'b-')
plt.plot(x,norm.pdf(x,1,0.5 ),'r:')
plt.legend(['Stam1','Stam2'],loc=4)
plt.show()

# %%
values = [65,25,10]
colors=['r','b','g']
labels = ['Republicans','Democrats','Gators']
explode = [0.2,0.1,0.4]
plt.pie(values,colors=colors,labels =labels,explode=explode)
plt.title("Trump biggest day ever!")
plt.show()

# %%
plt.bar(range(0,3),values,color=colors)
# Out:
# <BarContainer object of 3 artists>

# %%
from pylab import randn
X = randn(500)
Y = randn(500)
plt.scatter(X,Y)
plt.show()

# %%
uniformskewed = np.random.rand(100)*100-40
high_outliers = np.random.rand(10)*50+100
low_outliers = np.random.rand(10)* -50 -100
data = np.concatenate((uniformskewed,high_outliers,low_outliers))
len(data)
# Out:
# 120

# %%
plt.boxplot(data)
plt.show()

# %%
pwd
# Out:
# 'C:\\'
