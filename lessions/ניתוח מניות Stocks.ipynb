# %%
# tables and math
import pandas as pd
from pandas import Series,DataFrame
import numpy as np
# visualization
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
# due to a bug
pd.core.common.is_list_like = pd.api.types.is_list_like

# %%
from pandas_datareader import DataReader
from pandas_datareader import data as pdr

# %%
from datetime import datetime
from __future__ import division

# %%
tech_list = ['AAPL','MSFT','AMZN','IBM']
end = datetime(2018,4,4,18,00)
start = datetime(end.year - 1, end.month, end.day)

# %%
symbols = {stock:DataReader(stock,'yahoo',start,end) for stock in tech_list}

# %%
symbols['AAPL'].head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-04-04  144.889999  143.169998  143.250000  144.770004  19891400.0
# 2017-04-05  145.460007  143.809998  144.220001  144.020004  27717900.0
# 2017-04-06  144.520004  143.449997  144.289993  143.660004  21149000.0
# 2017-04-07  144.179993  143.270004  143.729996  143.339996  16672200.0
# 2017-04-10  143.880005  142.899994  143.600006  143.169998  18933400.0
#
#              Adj Close
# Date
# 2017-04-04  140.979980
# 2017-04-05  140.249619
# 2017-04-06  139.899048
# 2017-04-07  139.587402
# 2017-04-10  139.421860

# %%
symbols['AAPL'].describe()
# Out:
#              High         Low        Open       Close        Volume  \
# count  252.000000  252.000000  252.000000  252.000000  2.520000e+02
# mean   161.881706  159.393374  160.651389  160.669802  2.973645e+07
# std     11.532459   11.252567   11.349264   11.367555  1.233815e+07
# min    141.880005  140.059998  141.220001  140.679993  1.402670e+07
# 25%    153.904999  150.987503  152.989998  152.754997  2.108535e+07
# 50%    160.710007  158.055000  159.305000  159.704994  2.625485e+07
# 75%    172.962498  170.119999  171.850002  171.534996  3.508818e+07
# max    183.500000  180.210007  182.589996  181.720001  8.659380e+07
#
#         Adj Close
# count  252.000000
# mean   157.802519
# std     11.808918
# min    136.997055
# 25%    149.225685
# 50%    156.779167
# 75%    169.247177
# max    179.762085

# %%
symbols['AAPL'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 252 entries, 2017-04-04 to 2018-04-04
# Data columns (total 6 columns):
# High         252 non-null float64
# Low          252 non-null float64
# Open         252 non-null float64
# Close        252 non-null float64
# Volume       252 non-null float64
# Adj Close    252 non-null float64
# dtypes: float64(6)
# memory usage: 13.8 KB

# %%
symbols['AAPL']['Close'].plot(legend=True, figsize=(10,4))

# %%
symbols['AAPL']['Volume'].plot(legend=True, figsize=(10,4))

# %%
ma_day = [10,20,50]
for ma in ma_day:
    column_name = "MA for %s days" % (str(ma))
    symbols["AAPL"][column_name] = symbols['AAPL']['Close'].rolling(window=ma).mean()

# %%
symbols["AAPL"][['Close','MA for 10 days','MA for 20 days','MA for 50 days']].plot(figsize=(10,4))

# %%
symbols['AAPL']['Daily Return'] = symbols['AAPL']['Close'].pct_change()
symbols['AAPL']['Daily Return'].plot(figsize=(10,4),legend=True,linestyle='--',marker='o')

# %%
sns.distplot(symbols['AAPL']['Daily Return'].dropna(),bins=100,color='orange')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
tech_list
# Out:
# ['AAPL', 'MSFT', 'AMZN', 'IBM']
