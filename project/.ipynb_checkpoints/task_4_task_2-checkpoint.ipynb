# %%
# incase jupyter and global python version are different 
# import os
# os.environ["PYSPARK_PYTHON"]="/usr/bin/python3.5"

from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("my-spark-app").config('spark.executor.cores', '1').getOrCreate()

# %%
import pyspark.sql.functions as f


df = spark.read.csv("./resources/Hotels_data_Changed.csv",inferSchema=True,header=True)

def drop_outliers(df, field_name):
    per75 = df.approxQuantile(field_name, [0.75], 0.00001)[0]
    per25 = df.approxQuantile(field_name, [0.25], 0.00001)[0]
    distance = 1.5*(per75-per25)
    print(per75, per25, distance)

    return df.filter(f.col(field_name)<=(distance+per75)).filter(f.col(field_name)>=(per25-distance))
    df = df.filter('1!=1')

len_before = df.count()
field = 'DiscountPerc'

df = drop_outliers(df, field)
print("Number of rows after removing outliers: {}, down by {}%".format(df.count(),
                                                                       round((len_before - df.count()) / len_before * 100),
                                                                       2))
# Out:
# 187848
# 10.933940774487471 4.844961240310078 9.13346930126609
# Number of rows after removing outliers: 177121, down by 6%

# %%
from pyspark.mllib.regression import LabeledPoint

used_features = [
    "WeekDay",
    "Snapshot Date",
    "Checkin Date",
    "DayDiff",
    "Hotel Name"
]


len_before = df.count()

max_discount = df.groupBy([df[column] for column in used_features]).agg(f.max("DiscountPerc").alias("mx")).alias("maxs").select(
    [f.col("mx")] + [f.col(column).alias("max_" + column) for column in used_features])

df = df.join(max_discount,(
    (f.col("DiscountPerc")==f.col("mx")) & 
    (f.col("WeekDay")==f.col("max_WeekDay")) &
    (f.col("Snapshot Date")==f.col("max_Snapshot Date")) &
    (f.col("Checkin Date")==f.col("max_Checkin Date")) &
    (f.col("DayDiff")==f.col("max_DayDiff")) &
    (f.col("Hotel Name")==f.col("max_Hotel Name"))
),"inner").distinct().select(df.columns)

print("Number of rows after GroupBy the data to take maximum discount price: {}, down by {}%".format(df.count(),
                                                                                                     round((
                                                                                                                       len_before - df.count()
                                                                                                                   ) / len_before * 100),
                                                                                                     2))
# Out:
# Number of rows after GroupBy the data to take maximum discount price: 113144, down by 36%

# %%
from pyspark.sql.functions import udf, lit
my_date_format = udf(lambda d, fmt: d.strftime(fmt))

df = df.select(df.columns + [
        my_date_format(f.col("Snapshot Date"), lit("%d-%m-%Y")).alias("Snapshot Date_str"),
        my_date_format(f.col("Checkin Date"), lit("%d-%m-%Y")).alias("Checkin Date_str")
    ]
)

# %%
from pyspark.ml.feature import StringIndexer
from pyspark.ml import Pipeline


indexers = [StringIndexer(inputCol=column, outputCol=column + "_index").fit(df) for column, type in df.dtypes
            if type in ('string')]
pipeline = Pipeline(stages=indexers)
df = pipeline.fit(df).transform(df)

for column in df.dtypes:
    print (column)
# Out:
# ('_c0', 'int')
# ('Snapshot ID', 'int')
# ('Snapshot Date', 'timestamp')
# ('Checkin Date', 'timestamp')
# ('Days', 'int')
# ('Original Price', 'int')
# ('Discount Price', 'int')
# ('Discount Code', 'int')
# ('Available Rooms', 'int')
# ('Hotel Name', 'string')
# ('Hotel Stars', 'int')
# ('DayDiff', 'int')
# ('WeekDay', 'string')
# ('DiscountDiff', 'int')
# ('DiscountPerc', 'double')
# ('Snapshot Date_str', 'string')
# ('Checkin Date_str', 'string')
# ('Hotel Name_index', 'double')
# ('WeekDay_index', 'double')
# ('Snapshot Date_str_index', 'double')
# ('Checkin Date_str_index', 'double')

# %%
used_features = [
    "WeekDay_index",
    "Snapshot Date_str_index",
    "Checkin Date_str_index",
    "DayDiff",
    "Hotel Name_index"
]

def parseLine(line):
    label = int(line["Discount Code"])
    features = [line[column] for column in used_features]
    return LabeledPoint(label, features)

# MAP to LabeledPoint used by mllib
df2= df.rdd.map(parseLine)

# %%
train, test = df2.randomSplit([0.7, 0.3])

# %%
from pyspark.mllib.classification import NaiveBayes
model = NaiveBayes.train(train, 1.0)

# %%
# Make prediction and test accuracy.
predictionAndLabel = test.map(lambda p : (float(model.predict(p.features)), p.label))

# %%
from pyspark.mllib.evaluation import MulticlassMetrics
# Instantiate metrics object
metrics = MulticlassMetrics(predictionAndLabel)

# Overall statistics
precision = metrics.precision()
recall = metrics.recall()
f1Score = metrics.fMeasure()
print("Summary Stats")
print("Precision = %s" % precision)
print("Recall = %s" % recall)
print("F1 Score = %s" % f1Score)

# Statistics by class
labels = df2.map(lambda lp: lp.label).distinct().collect()
for label in sorted(labels):
    print("Class %s precision = %s" % (label, metrics.precision(label)))
    print("Class %s recall = %s" % (label, metrics.recall(label)))
    print("Class %s F1 Measure = %s" % (label, metrics.fMeasure(label, beta=1.0)))
# Out:
# Summary Stats
# Precision = 0.277771229889799
# Recall = 0.277771229889799
# F1 Score = 0.277771229889799
# Class 1.0 precision = 0.257393850658858
# Class 1.0 recall = 0.3325346784363178
# Class 1.0 F1 Measure = 0.2901788170563962
# Class 2.0 precision = 0.3240058910162003
# Class 2.0 recall = 0.06148686416992733
# Class 2.0 F1 Measure = 0.10335917312661498
# Class 3.0 precision = 0.311346752935538
# Class 3.0 recall = 0.5255865695792881
# Class 3.0 F1 Measure = 0.39104589917231003
# Class 4.0 precision = 0.1879532634971797
# Class 4.0 recall = 0.17322688451541032
# Class 4.0 F1 Measure = 0.18028985507246378

# %%
df.agg(f.max('Checkin Date_str_index').alias("max")).first().max
# Out:
# 201.0

# %%
df[used_features].show()
# Out:
# +-------------+-----------------------+----------------------+-------+----------------+
# |WeekDay_index|Snapshot Date_str_index|Checkin Date_str_index|DayDiff|Hotel Name_index|
# +-------------+-----------------------+----------------------+-------+----------------+
# |          4.0|                   59.0|                 148.0|      3|            29.0|
# |          3.0|                   52.0|                  12.0|     14|            31.0|
# |          2.0|                   56.0|                 102.0|      9|           216.0|
# |          5.0|                    6.0|                  65.0|     14|            71.0|
# |          5.0|                    3.0|                  45.0|      6|            71.0|
# |          1.0|                   82.0|                   9.0|     28|             9.0|
# |          4.0|                   54.0|                  70.0|     29|           133.0|
# |          6.0|                  125.0|                 136.0|     16|            67.0|
# |          6.0|                   40.0|                 176.0|      7|           116.0|
# |          3.0|                   90.0|                 127.0|      4|           184.0|
# |          5.0|                   96.0|                 147.0|      2|             7.0|
# |          6.0|                    6.0|                  97.0|      6|            48.0|
# |          4.0|                  109.0|                 179.0|      4|            26.0|
# |          4.0|                    9.0|                 134.0|     12|           375.0|
# |          2.0|                   36.0|                 102.0|      8|            18.0|
# |          4.0|                  132.0|                 124.0|     27|           355.0|
# |          3.0|                   42.0|                  18.0|      5|            43.0|
# |          1.0|                  137.0|                 128.0|     19|            44.0|
# |          1.0|                   90.0|                 128.0|      6|            65.0|
# |          5.0|                    3.0|                  74.0|     34|            43.0|
# +-------------+-----------------------+----------------------+-------+----------------+
# only showing top 20 rows

# %%
from pyspark.mllib.tree import DecisionTree, DecisionTreeModel


train, test = df2.randomSplit([0.7, 0.3])

# extract categories max value to give categoricalFeaturesInfo range for each feature
model = DecisionTree.trainClassifier(train, numClasses=5, categoricalFeaturesInfo={
    i : int(df.agg(f.max(column).alias("max")).first().max + 1)
        for i,column in enumerate(used_features) if i in [0]
},
                                     impurity='gini', maxDepth=20, maxBins=128)

# %%
predictions = model.predict(test.map(lambda x: x.features))
predictionAndLabel = test.map(lambda lp: lp.label).zip(predictions)
testErr = predictionAndLabel.filter(
    lambda lp: lp[0] != lp[1]).count() / float(test.count())

print('Test Error = ' + str(testErr))
print('Learned classification tree model:')
print(model.toDebugString())
# Out:
# Test Error = 0.36112173733925784
# Learned classification tree model:
# DecisionTreeModel classifier of depth 20 with 31783 nodes
#   If (feature 0 in {1.0,2.0,3.0,5.0})
#    If (feature 0 in {3.0,2.0,1.0})
#     If (feature 0 in {2.0,1.0})
#      If (feature 4 <= 45.5)
#       If (feature 4 <= 10.5)
#        If (feature 4 <= 5.5)
#         If (feature 4 <= 2.5)
#          If (feature 4 <= 1.5)
#           If (feature 2 <= 106.5)
#            If (feature 0 in {1.0})
#             If (feature 4 <= 0.5)
#              If (feature 2 <= 23.5)
#               If (feature 3 <= 33.5)
#                Predict: 1.0
#               Else (feature 3 > 33.5)
#                If (feature 1 <= 31.5)
#                 Predict: 2.0
#                Else (feature 1 > 31.5)
#                 Predict: 1.0
#              Else (feature 2 > 23.5)
#               If (feature 3 <= 16.5)
#                If (feature 2 <= 84.5)
#                 If (feature 2 <= 26.5)
#                  Predict: 3.0
#                 Else (feature 2 > 26.5)
#                  If (feature 2 <= 55.5)
#                   If (feature 1 <= 131.5)
#                    If (feature 1 <= 99.5)
#                     If (feature 1 <= 81.5)
#                      Predict: 4.0
#                     Else (feature 1 > 81.5)
#                      Predict: 2.0
#                    Else (feature 1 > 99.5)
#                     Predict: 4.0
#                   Else (feature 1 > 131.5)
#                    If (feature 1 <= 136.5)
#                     Predict: 2.0
#                    Else (feature 1 > 136.5)
#                     If (feature 1 <= 147.5)
#                      Predict: 2.0
#                     Else (feature 1 > 147.5)
#                      Predict: 4.0
#                  Else (feature 2 > 55.5)
#                   If (feature 3 <= 3.5)
#                    If (feature 3 <= 1.5)
#                     Predict: 2.0
#                    Else (feature 3 > 1.5)
#                     Predict: 1.0
#                   Else (feature 3 > 3.5)
#                    Predict: 2.0
#                Else (feature 2 > 84.5)
#                 If (feature 3 <= 5.5)
#                  Predict: 4.0
#                 Else (feature 3 > 5.5)
#                  If (feature 1 <= 112.5)
#                   If (feature 3 <= 10.5)
#                    Predict: 3.0
#                   Else (feature 3 > 10.5)
#                    If (feature 3 <= 12.5)
#                     Predict: 4.0
#                    Else (feature 3 > 12.5)
#                     Predict: 3.0
#                  Else (feature 1 > 112.5)
#                   Predict: 3.0
#               Else (feature 3 > 16.5)
#                If (feature 3 <= 21.5)
#                 If (feature 2 <= 33.5)
#                  If (feature 3 <= 18.5)
#                   Predict: 2.0
#                  Else (feature 3 > 18.5)
#                   Predict: 1.0
#                 Else (feature 2 > 33.5)
#                  Predict: 3.0
#                Else (feature 3 > 21.5)
#                 If (feature 1 <= 115.5)
#                  If (feature 1 <= 70.5)
#                   If (feature 2 <= 26.5)
#                    Predict: 4.0
#                   Else (feature 2 > 26.5)
#                    If (feature 2 <= 98.5)
#                     Predict: 3.0
#                    Else (feature 2 > 98.5)
#                     If (feature 1 <= 9.5)
#                      Predict: 3.0
#                     Else (feature 1 > 9.5)
#                      If (feature 3 <= 26.5)
#                       Predict: 4.0
#                      Else (feature 3 > 26.5)
#                       Predict: 3.0
#                  Else (feature 1 > 70.5)
#                   If (feature 3 <= 32.5)
#                    Predict: 3.0
#                   Else (feature 3 > 32.5)
#                    Predict: 4.0
#                 Else (feature 1 > 115.5)
#                  Predict: 4.0
#             Else (feature 4 > 0.5)
#              If (feature 2 <= 98.5)
#               If (feature 2 <= 67.5)
#                If (feature 2 <= 26.5)
#                 If (feature 2 <= 15.5)
#                  If (feature 3 <= 14.5)
#                   If (feature 2 <= 8.5)
#                    If (feature 2 <= 5.5)
#                     Predict: 2.0
#                    Else (feature 2 > 5.5)
#                     If (feature 3 <= 6.5)
#                      Predict: 4.0
#                     Else (feature 3 > 6.5)
#                      Predict: 1.0
#                   Else (feature 2 > 8.5)
#                    If (feature 3 <= 3.5)
#                     Predict: 1.0
#                    Else (feature 3 > 3.5)
#                     If (feature 2 <= 14.5)
#                      Predict: 3.0
#                     Else (feature 2 > 14.5)
#                      If (feature 1 <= 7.5)
#                       Predict: 3.0
#                      Else (feature 1 > 7.5)
#                       Predict: 2.0
#                  Else (feature 3 > 14.5)
#                   If (feature 2 <= 5.5)
#                    If (feature 3 <= 20.5)
#                     Predict: 1.0
#                    Else (feature 3 > 20.5)
#                     Predict: 3.0
#                   Else (feature 2 > 5.5)
#                    Predict: 3.0
#                 Else (feature 2 > 15.5)
#                  If (feature 3 <= 15.5)
#                   Predict: 3.0
#                  Else (feature 3 > 15.5)
#                   If (feature 3 <= 27.5)
#                    If (feature 1 <= 43.5)
#                     Predict: 2.0
#                    Else (feature 1 > 43.5)
#                     If (feature 2 <= 23.5)
#                      Predict: 4.0
#                     Else (feature 2 > 23.5)
#                      If (feature 3 <= 16.5)
#                       Predict: 3.0
#                      Else (feature 3 > 16.5)
#                       Predict: 2.0
#                   Else (feature 3 > 27.5)
#                    If (feature 2 <= 23.5)
#                     If (feature 3 <= 28.5)
#                      If (feature 1 <= 32.5)
#                       Predict: 3.0
#                      Else (feature 1 > 32.5)
#                       Predict: 4.0
#                     Else (feature 3 > 28.5)
#                      Predict: 3.0
#                    Else (feature 2 > 23.5)
#                     Predict: 2.0
#                Else (feature 2 > 26.5)
#                 If (feature 2 <= 55.5)
#                  If (feature 2 <= 52.5)
#                   If (feature 2 <= 33.5)
#                    If (feature 1 <= 79.5)
#                     If (feature 3 <= 3.5)
#                      Predict: 1.0
#                     Else (feature 3 > 3.5)
#                      Predict: 3.0
#                    Else (feature 1 > 79.5)
#                     Predict: 1.0
#                   Else (feature 2 > 33.5)
#                    If (feature 3 <= 6.5)
#                     If (feature 1 <= 56.5)
#                      Predict: 1.0
#                     Else (feature 1 > 56.5)
#                      If (feature 1 <= 81.5)
#                       Predict: 2.0
#                      Else (feature 1 > 81.5)
#                       Predict: 3.0
#                    Else (feature 3 > 6.5)
#                     If (feature 1 <= 90.5)
#                      Predict: 4.0
#                     Else (feature 1 > 90.5)
#                      If (feature 1 <= 102.5)
#                       Predict: 3.0
#                      Else (feature 1 > 102.5)
#                       Predict: 4.0
#                  Else (feature 2 > 52.5)
#                   If (feature 1 <= 142.5)
#                    Predict: 1.0
#                   Else (feature 1 > 142.5)
#                    Predict: 2.0
#                 Else (feature 2 > 55.5)
#                  If (feature 1 <= 46.5)
#                   If (feature 3 <= 13.5)
#                    If (feature 3 <= 1.5)
#                     Predict: 4.0
#                    Else (feature 3 > 1.5)
#                     Predict: 3.0
#                   Else (feature 3 > 13.5)
#                    If (feature 1 <= 39.5)
#                     Predict: 2.0
#                    Else (feature 1 > 39.5)
#                     Predict: 4.0
#                  Else (feature 1 > 46.5)
#                   Predict: 3.0
#               Else (feature 2 > 67.5)
#                If (feature 3 <= 29.5)
#                 If (feature 3 <= 3.5)
#                  If (feature 1 <= 87.5)
#                   Predict: 1.0
#                  Else (feature 1 > 87.5)
#                   Predict: 3.0
#                 Else (feature 3 > 3.5)
#                  Predict: 3.0
#                Else (feature 3 > 29.5)
#                 If (feature 1 <= 58.5)
#                  Predict: 3.0
#                 Else (feature 1 > 58.5)
#                  Predict: 2.0
#              Else (feature 2 > 98.5)
#               If (feature 3 <= 8.5)
#                Predict: 3.0
#               Else (feature 3 > 8.5)
#                Predict: 2.0
#            Else (feature 0 not in {1.0})
#             If (feature 2 <= 86.5)
#              If (feature 2 <= 11.5)
#               If (feature 3 <= 20.5)
#                If (feature 2 <= 2.5)
#                 If (feature 3 <= 3.5)
#                  If (feature 1 <= 32.5)
#                   Predict: 3.0
#                  Else (feature 1 > 32.5)
#                   Predict: 1.0
#                 Else (feature 3 > 3.5)
#                  If (feature 1 <= 21.5)
#                   Predict: 4.0
#                  Else (feature 1 > 21.5)
#                   If (feature 1 <= 25.5)
#                    Predict: 2.0
#                   Else (feature 1 > 25.5)
#                    Predict: 4.0
#                Else (feature 2 > 2.5)
#                 If (feature 3 <= 13.5)
#                  If (feature 1 <= 15.5)
#                   Predict: 3.0
#                  Else (feature 1 > 15.5)
#                   If (feature 2 <= 6.5)
#                    Predict: 1.0
#                   Else (feature 2 > 6.5)
#                    Predict: 2.0
#                 Else (feature 3 > 13.5)
#                  Predict: 2.0
#               Else (feature 3 > 20.5)
#                Predict: 2.0
#              Else (feature 2 > 11.5)
#               If (feature 4 <= 0.5)
#                If (feature 2 <= 79.5)
#                 If (feature 1 <= 22.5)
#                  Predict: 1.0
#                 Else (feature 1 > 22.5)
#                  If (feature 3 <= 29.5)
#                   If (feature 1 <= 117.5)
#                    If (feature 3 <= 14.5)
#                     If (feature 1 <= 79.5)
#                      If (feature 3 <= 13.5)
#                       Predict: 2.0
#                      Else (feature 3 > 13.5)
#                       Predict: 3.0
#                     Else (feature 1 > 79.5)
#                      Predict: 3.0
#                    Else (feature 3 > 14.5)
#                     If (feature 1 <= 95.5)
#                      If (feature 1 <= 70.5)
#                       Predict: 2.0
#                      Else (feature 1 > 70.5)
#                       Predict: 1.0
#                     Else (feature 1 > 95.5)
#                      Predict: 2.0
#                   Else (feature 1 > 117.5)
#                    If (feature 1 <= 120.5)
#                     Predict: 1.0
#                    Else (feature 1 > 120.5)
#                     If (feature 1 <= 139.5)
#                      Predict: 3.0
#                     Else (feature 1 > 139.5)
#                      Predict: 2.0
#                  Else (feature 3 > 29.5)
#                   If (feature 1 <= 95.5)
#                    Predict: 3.0
#                   Else (feature 1 > 95.5)
#                    Predict: 2.0
#                Else (feature 2 > 79.5)
#                 Predict: 3.0
#               Else (feature 4 > 0.5)
#                If (feature 2 <= 28.5)
#                 If (feature 3 <= 23.5)
#                  If (feature 1 <= 115.5)
#                   Predict: 3.0
#                  Else (feature 1 > 115.5)
#                   If (feature 1 <= 141.5)
#                    Predict: 2.0
#                   Else (feature 1 > 141.5)
#                    Predict: 3.0
#                 Else (feature 3 > 23.5)
#                  If (feature 3 <= 30.5)
#                   Predict: 4.0
#                  Else (feature 3 > 30.5)
#                   If (feature 1 <= 72.5)
#                    Predict: 4.0
#                   Else (feature 1 > 72.5)
#                    Predict: 3.0
#                Else (feature 2 > 28.5)
#                 If (feature 1 <= 18.5)
#                  If (feature 2 <= 54.5)
#                   If (feature 3 <= 6.5)
#                    Predict: 2.0
#                   Else (feature 3 > 6.5)
#                    Predict: 1.0
#                  Else (feature 2 > 54.5)
#                   Predict: 3.0
#                 Else (feature 1 > 18.5)
#                  If (feature 3 <= 14.5)
#                   If (feature 2 <= 49.5)
#                    If (feature 2 <= 31.5)
#                     If (feature 1 <= 38.5)
#                      If (feature 1 <= 25.5)
#                       Predict: 3.0
#                      Else (feature 1 > 25.5)
#                       Predict: 2.0
#                     Else (feature 1 > 38.5)
#                      Predict: 3.0
#                    Else (feature 2 > 31.5)
#                     If (feature 2 <= 44.5)
#                      Predict: 4.0
#                     Else (feature 2 > 44.5)
#                      If (feature 3 <= 1.5)
#                       Predict: 1.0
#                      Else (feature 3 > 1.5)
#                       Predict: 3.0
#                   Else (feature 2 > 49.5)
#                    If (feature 2 <= 79.5)
#                     Predict: 2.0
#                    Else (feature 2 > 79.5)
#                     If (feature 1 <= 96.5)
#                      Predict: 3.0
#                     Else (feature 1 > 96.5)
#                      Predict: 2.0
#                  Else (feature 3 > 14.5)
#                   If (feature 2 <= 44.5)
#                    If (feature 2 <= 30.5)
#                     Predict: 4.0
#                    Else (feature 2 > 30.5)
#                     If (feature 2 <= 31.5)
#                      Predict: 2.0
#                     Else (feature 2 > 31.5)
#                      Predict: 3.0
#                   Else (feature 2 > 44.5)
#                    If (feature 2 <= 60.5)
#                     If (feature 1 <= 29.5)
#                      Predict: 2.0
#                     Else (feature 1 > 29.5)
#                      Predict: 4.0
#                    Else (feature 2 > 60.5)
#                     If (feature 1 <= 53.5)
#                      Predict: 3.0
#                     Else (feature 1 > 53.5)
#                      Predict: 2.0
#             Else (feature 2 > 86.5)
#              If (feature 1 <= 5.5)
#               Predict: 3.0
#              Else (feature 1 > 5.5)
#               Predict: 2.0
#           Else (feature 2 > 106.5)
#            If (feature 2 <= 130.5)
#             If (feature 4 <= 0.5)
#              If (feature 2 <= 109.5)
#               If (feature 3 <= 22.5)
#                If (feature 1 <= 93.5)
#                 Predict: 3.0
#                Else (feature 1 > 93.5)
#                 If (feature 3 <= 2.5)
#                  Predict: 2.0
#                 Else (feature 3 > 2.5)
#                  If (feature 1 <= 99.5)
#                   If (feature 3 <= 20.5)
#                    Predict: 2.0
#                   Else (feature 3 > 20.5)
#                    Predict: 1.0
#                  Else (feature 1 > 99.5)
#                   If (feature 1 <= 130.5)
#                    Predict: 1.0
#                   Else (feature 1 > 130.5)
#                    If (feature 3 <= 8.5)
#                     If (feature 3 <= 7.5)
#                      If (feature 3 <= 5.5)
#                       Predict: 1.0
#                      Else (feature 3 > 5.5)
#                       Predict: 2.0
#                     Else (feature 3 > 7.5)
#                      Predict: 4.0
#                    Else (feature 3 > 8.5)
#                     Predict: 1.0
#               Else (feature 3 > 22.5)
#                Predict: 1.0
#              Else (feature 2 > 109.5)
#               Predict: 2.0
#             Else (feature 4 > 0.5)
#              If (feature 2 <= 109.5)
#               Predict: 3.0
#              Else (feature 2 > 109.5)
#               If (feature 3 <= 22.5)
#                If (feature 1 <= 45.5)
#                 Predict: 3.0
#                Else (feature 1 > 45.5)
#                 If (feature 3 <= 13.5)
#                  If (feature 1 <= 59.5)
#                   Predict: 4.0
#                  Else (feature 1 > 59.5)
#                   If (feature 1 <= 63.5)
#                    If (feature 3 <= 4.5)
#                     Predict: 1.0
#                    Else (feature 3 > 4.5)
#                     Predict: 3.0
#                   Else (feature 1 > 63.5)
#                    If (feature 3 <= 2.5)
#                     If (feature 3 <= 1.5)
#                      Predict: 4.0
#                     Else (feature 3 > 1.5)
#                      If (feature 1 <= 92.5)
#                       Predict: 3.0
#                      Else (feature 1 > 92.5)
#                       Predict: 2.0
#                    Else (feature 3 > 2.5)
#                     Predict: 4.0
#                 Else (feature 3 > 13.5)
#                  Predict: 3.0
#               Else (feature 3 > 22.5)
#                Predict: 4.0
#            Else (feature 2 > 130.5)
#             If (feature 3 <= 8.5)
#              If (feature 4 <= 0.5)
#               If (feature 1 <= 50.5)
#                Predict: 2.0
#               Else (feature 1 > 50.5)
#                If (feature 1 <= 144.5)
#                 If (feature 1 <= 134.5)
#                  Predict: 2.0
#                 Else (feature 1 > 134.5)
#                  Predict: 1.0
#                Else (feature 1 > 144.5)
#                 Predict: 2.0
#              Else (feature 4 > 0.5)
#               If (feature 1 <= 59.5)
#                If (feature 0 in {1.0})
#                 Predict: 3.0
#                Else (feature 0 not in {1.0})
#                 Predict: 1.0
#               Else (feature 1 > 59.5)
#                Predict: 3.0
#             Else (feature 3 > 8.5)
#              If (feature 4 <= 0.5)
#               If (feature 2 <= 162.5)
#                If (feature 1 <= 123.5)
#                 If (feature 1 <= 105.5)
#                  If (feature 3 <= 21.5)
#                   Predict: 1.0
#                  Else (feature 3 > 21.5)
#                   If (feature 3 <= 32.5)
#                    If (feature 3 <= 29.5)
#                     If (feature 3 <= 28.5)
#                      If (feature 1 <= 90.5)
#                       Predict: 2.0
#                      Else (feature 1 > 90.5)
#                       Predict: 1.0
#                     Else (feature 3 > 28.5)
#                      If (feature 0 in {1.0})
#                       Predict: 2.0
#                      Else (feature 0 not in {1.0})
#                       Predict: 1.0
#                    Else (feature 3 > 29.5)
#                     If (feature 1 <= 93.5)
#                      If (feature 3 <= 30.5)
#                       Predict: 2.0
#                      Else (feature 3 > 30.5)
#                       Predict: 1.0
#                     Else (feature 1 > 93.5)
#                      Predict: 2.0
#                   Else (feature 3 > 32.5)
#                    If (feature 1 <= 96.5)
#                     If (feature 0 in {1.0})
#                      Predict: 3.0
#                     Else (feature 0 not in {1.0})
#                      Predict: 1.0
#                    Else (feature 1 > 96.5)
#                     Predict: 4.0
#                 Else (feature 1 > 105.5)
#                  If (feature 3 <= 24.5)
#                   If (feature 1 <= 114.5)
#                    If (feature 3 <= 21.5)
#                     If (feature 3 <= 19.5)
#                      If (feature 0 in {1.0})
#                       Predict: 1.0
#                      Else (feature 0 not in {1.0})
#                       Predict: 2.0
#                     Else (feature 3 > 19.5)
#                      If (feature 0 in {1.0})
#                       Predict: 2.0
#                      Else (feature 0 not in {1.0})
#                       Predict: 1.0
#                    Else (feature 3 > 21.5)
#                     Predict: 3.0
#                   Else (feature 1 > 114.5)
#                    If (feature 0 in {1.0})
#                     Predict: 1.0
#                    Else (feature 0 not in {1.0})
#                     Predict: 3.0
#                  Else (feature 3 > 24.5)
#                   If (feature 1 <= 107.5)
#                    If (feature 0 in {1.0})
#                     Predict: 1.0
#                    Else (feature 0 not in {1.0})
#                     Predict: 2.0
#                   Else (feature 1 > 107.5)
#                    If (feature 0 in {1.0})
#                     If (feature 1 <= 112.5)
#                      Predict: 2.0
#                     Else (feature 1 > 112.5)
#                      If (feature 1 <= 119.5)
#                       Predict: 2.0
#                      Else (feature 1 > 119.5)
#                       Predict: 1.0
#                    Else (feature 0 not in {1.0})
#                     Predict: 1.0
#                Else (feature 1 > 123.5)
#                 If (feature 3 <= 19.5)
#                  If (feature 3 <= 14.5)
#                   If (feature 1 <= 136.5)
#                    Predict: 1.0
#                   Else (feature 1 > 136.5)
#                    If (feature 1 <= 144.5)
#                     If (feature 3 <= 12.5)
#                      Predict: 3.0
#                     Else (feature 3 > 12.5)
#                      If (feature 0 in {1.0})
#                       Predict: 3.0
#                      Else (feature 0 not in {1.0})
#                       Predict: 2.0
#                    Else (feature 1 > 144.5)
#                     If (feature 0 in {1.0})
#                      Predict: 2.0
#                     Else (feature 0 not in {1.0})
#                      Predict: 1.0
#                  Else (feature 3 > 14.5)
#                   If (feature 0 in {1.0})
#                    Predict: 1.0
#                   Else (feature 0 not in {1.0})
#                    If (feature 3 <= 15.5)
#                     If (feature 1 <= 142.5)
#                      Predict: 2.0
#                     Else (feature 1 > 142.5)
#                      Predict: 1.0
#                    Else (feature 3 > 15.5)
#                     Predict: 1.0
#                 Else (feature 3 > 19.5)
#                  If (feature 1 <= 141.5)
#                   If (feature 0 in {1.0})
#                    If (feature 1 <= 130.5)
#                     Predict: 1.0
#                    Else (feature 1 > 130.5)
#                     If (feature 3 <= 20.5)
#                      Predict: 4.0
#                     Else (feature 3 > 20.5)
#                      Predict: 2.0
#                   Else (feature 0 not in {1.0})
#                    Predict: 1.0
#                  Else (feature 1 > 141.5)
#                   Predict: 1.0
#               Else (feature 2 > 162.5)
#                If (feature 2 <= 176.5)
#                 If (feature 3 <= 31.5)
#                  If (feature 3 <= 20.5)
#                   Predict: 1.0
#                  Else (feature 3 > 20.5)
#                   If (feature 3 <= 21.5)
#                    Predict: 2.0
#                   Else (feature 3 > 21.5)
#                    If (feature 1 <= 131.5)
#                     If (feature 1 <= 114.5)
#                      Predict: 1.0
#                     Else (feature 1 > 114.5)
#                      Predict: 2.0
#                    Else (feature 1 > 131.5)
#                     Predict: 1.0
#                 Else (feature 3 > 31.5)
#                  Predict: 1.0
#                Else (feature 2 > 176.5)
#                 If (feature 3 <= 27.5)
#                  Predict: 1.0
#                 Else (feature 3 > 27.5)
#                  If (feature 2 <= 187.5)
#                   If (feature 1 <= 147.5)
#                    If (feature 1 <= 107.5)
#                     Predict: 1.0
#                    Else (feature 1 > 107.5)
#                     If (feature 1 <= 119.5)
#                      Predict: 1.0
#                     Else (feature 1 > 119.5)
#                      If (feature 3 <= 33.5)
#                       Predict: 1.0
#                      Else (feature 3 > 33.5)
#                       Predict: 2.0
#                   Else (feature 1 > 147.5)
#                    Predict: 1.0
#                  Else (feature 2 > 187.5)
#                   Predict: 2.0
#              Else (feature 4 > 0.5)
#               If (feature 2 <= 160.5)
#                If (feature 0 in {1.0})
#                 If (feature 2 <= 149.5)
#                  Predict: 2.0
#                 Else (feature 2 > 149.5)
#                  If (feature 1 <= 94.5)
#                   Predict: 2.0
#                  Else (feature 1 > 94.5)
#                   If (feature 1 <= 98.5)
#                    Predict: 3.0
#                   Else (feature 1 > 98.5)
#                    Predict: 2.0
#                Else (feature 0 not in {1.0})
#                 Predict: 4.0
#               Else (feature 2 > 160.5)
#                If (feature 3 <= 28.5)
#                 Predict: 1.0
#                Else (feature 3 > 28.5)
#                 Predict: 2.0
#          Else (feature 4 > 1.5)
#           If (feature 0 in {1.0})
#            If (feature 1 <= 42.5)
#             If (feature 2 <= 52.5)
#              If (feature 2 <= 14.5)
#               Predict: 2.0
#              Else (feature 2 > 14.5)
#               If (feature 2 <= 15.5)
#                If (feature 3 <= 24.5)
#                 Predict: 3.0
#                Else (feature 3 > 24.5)
#                 Predict: 2.0
#               Else (feature 2 > 15.5)
#                Predict: 2.0
#             Else (feature 2 > 52.5)
#              If (feature 2 <= 59.5)
#               If (feature 1 <= 4.5)
#                Predict: 3.0
#               Else (feature 1 > 4.5)
#                Predict: 4.0
#              Else (feature 2 > 59.5)
#               Predict: 2.0
#            Else (feature 1 > 42.5)
#             If (feature 2 <= 128.5)
#              If (feature 2 <= 55.5)
#               If (feature 2 <= 26.5)
#                If (feature 2 <= 20.5)
#                 If (feature 1 <= 110.5)
#                  If (feature 1 <= 46.5)
#                   If (feature 1 <= 44.5)
#                    Predict: 2.0
#                   Else (feature 1 > 44.5)
#                    If (feature 2 <= 15.5)
#                     Predict: 3.0
#                    Else (feature 2 > 15.5)
#                     Predict: 2.0
#                  Else (feature 1 > 46.5)
#                   If (feature 1 <= 70.5)
#                    Predict: 2.0
#                   Else (feature 1 > 70.5)
#                    If (feature 1 <= 72.5)
#                     If (feature 2 <= 5.5)
#                      Predict: 2.0
#                     Else (feature 2 > 5.5)
#                      If (feature 2 <= 15.5)
#                       Predict: 3.0
#                      Else (feature 2 > 15.5)
#                       Predict: 2.0
#                    Else (feature 1 > 72.5)
#                     Predict: 2.0
#                 Else (feature 1 > 110.5)
#                  Predict: 3.0
#                Else (feature 2 > 20.5)
#                 If (feature 3 <= 3.5)
#                  Predict: 2.0
#                 Else (feature 3 > 3.5)
#                  If (feature 3 <= 17.5)
#                   Predict: 3.0
#                  Else (feature 3 > 17.5)
#                   If (feature 2 <= 23.5)
#                    Predict: 2.0
#                   Else (feature 2 > 23.5)
#                    Predict: 3.0
#               Else (feature 2 > 26.5)
#                If (feature 1 <= 45.5)
#                 Predict: 4.0
#                Else (feature 1 > 45.5)
#                 Predict: 2.0
#              Else (feature 2 > 55.5)
#               If (feature 2 <= 59.5)
#                Predict: 4.0
#               Else (feature 2 > 59.5)
#                If (feature 3 <= 6.5)
#                 Predict: 2.0
#                Else (feature 3 > 6.5)
#                 If (feature 2 <= 98.5)
#                  Predict: 2.0
#                 Else (feature 2 > 98.5)
#                  If (feature 1 <= 71.5)
#                   If (feature 1 <= 54.5)
#                    Predict: 3.0
#                   Else (feature 1 > 54.5)
#                    If (feature 3 <= 29.5)
#                     Predict: 3.0
#                    Else (feature 3 > 29.5)
#                     Predict: 4.0
#                  Else (feature 1 > 71.5)
#                   Predict: 3.0
#             Else (feature 2 > 128.5)
#              If (feature 2 <= 176.5)
#               Predict: 2.0
#              Else (feature 2 > 176.5)
#               If (feature 3 <= 3.5)
#                Predict: 2.0
#               Else (feature 3 > 3.5)
#                If (feature 1 <= 133.5)
#                 Predict: 3.0
#                Else (feature 1 > 133.5)
#                 Predict: 1.0
#           Else (feature 0 not in {1.0})
#            If (feature 3 <= 1.5)
#             If (feature 1 <= 82.5)
#              Predict: 2.0
#             Else (feature 1 > 82.5)
#              If (feature 2 <= 31.5)
#               If (feature 1 <= 119.5)
#                Predict: 3.0
#               Else (feature 1 > 119.5)
#                Predict: 2.0
#              Else (feature 2 > 31.5)
#               Predict: 1.0
#            Else (feature 3 > 1.5)
#             If (feature 3 <= 23.5)
#              Predict: 1.0
#             Else (feature 3 > 23.5)
#              If (feature 2 <= 31.5)
#               Predict: 2.0
#              Else (feature 2 > 31.5)
#               If (feature 3 <= 29.5)
#                Predict: 1.0
#               Else (feature 3 > 29.5)
#                If (feature 1 <= 45.5)
#                 Predict: 1.0
#                Else (feature 1 > 45.5)
#                 If (feature 1 <= 57.5)
#                  Predict: 3.0
#                 Else (feature 1 > 57.5)
#                  Predict: 2.0
#         Else (feature 4 > 2.5)
#          If (feature 4 <= 3.5)
#           If (feature 2 <= 11.5)
#            If (feature 0 in {1.0})
#             If (feature 3 <= 17.5)
#              If (feature 1 <= 7.5)
#               Predict: 1.0
#              Else (feature 1 > 7.5)
#               If (feature 1 <= 52.5)
#                Predict: 4.0
#               Else (feature 1 > 52.5)
#                If (feature 1 <= 72.5)
#                 Predict: 3.0
#                Else (feature 1 > 72.5)
#                 Predict: 4.0
#             Else (feature 3 > 17.5)
#              Predict: 2.0
#            Else (feature 0 not in {1.0})
#             If (feature 3 <= 18.5)
#              If (feature 3 <= 15.5)
#               Predict: 3.0
#              Else (feature 3 > 15.5)
#               If (feature 1 <= 21.5)
#                Predict: 4.0
#               Else (feature 1 > 21.5)
#                Predict: 3.0
#             Else (feature 3 > 18.5)
#              If (feature 2 <= 6.5)
#               If (feature 1 <= 38.5)
#                If (feature 3 <= 27.5)
#                 Predict: 4.0
#                Else (feature 3 > 27.5)
#                 If (feature 2 <= 2.5)
#                  Predict: 3.0
#                 Else (feature 2 > 2.5)
#                  Predict: 4.0
#               Else (feature 1 > 38.5)
#                Predict: 3.0
#              Else (feature 2 > 6.5)
#               If (feature 3 <= 29.5)
#                Predict: 3.0
#               Else (feature 3 > 29.5)
#                If (feature 1 <= 21.5)
#                 Predict: 4.0
#                Else (feature 1 > 21.5)
#                 Predict: 2.0
#           Else (feature 2 > 11.5)
#            If (feature 2 <= 26.5)
#             If (feature 2 <= 20.5)
#              If (feature 3 <= 12.5)
#               If (feature 1 <= 38.5)
#                If (feature 1 <= 14.5)
#                 Predict: 3.0
#                Else (feature 1 > 14.5)
#                 If (feature 2 <= 14.5)
#                  If (feature 3 <= 2.5)
#                   Predict: 4.0
#                  Else (feature 3 > 2.5)
#                   Predict: 2.0
#                 Else (feature 2 > 14.5)
#                  Predict: 4.0
#               Else (feature 1 > 38.5)
#                Predict: 3.0
#              Else (feature 3 > 12.5)
#               If (feature 1 <= 48.5)
#                Predict: 4.0
#               Else (feature 1 > 48.5)
#                If (feature 1 <= 64.5)
#                 Predict: 3.0
#                Else (feature 1 > 64.5)
#                 Predict: 4.0
#             Else (feature 2 > 20.5)
#              If (feature 3 <= 22.5)
#               If (feature 1 <= 53.5)
#                Predict: 4.0
#               Else (feature 1 > 53.5)
#                If (feature 1 <= 117.5)
#                 If (feature 3 <= 1.5)
#                  Predict: 4.0
#                 Else (feature 3 > 1.5)
#                  If (feature 1 <= 64.5)
#                   Predict: 2.0
#                  Else (feature 1 > 64.5)
#                   If (feature 0 in {1.0})
#                    If (feature 1 <= 111.5)
#                     Predict: 2.0
#                    Else (feature 1 > 111.5)
#                     Predict: 3.0
#                   Else (feature 0 not in {1.0})
#                    Predict: 3.0
#                Else (feature 1 > 117.5)
#                 If (feature 3 <= 6.5)
#                  If (feature 1 <= 144.5)
#                   Predict: 2.0
#                  Else (feature 1 > 144.5)
#                   Predict: 1.0
#                 Else (feature 3 > 6.5)
#                  Predict: 1.0
#              Else (feature 3 > 22.5)
#               Predict: 2.0
#            Else (feature 2 > 26.5)
#             If (feature 2 <= 55.5)
#              If (feature 2 <= 52.5)
#               If (feature 2 <= 28.5)
#                Predict: 3.0
#               Else (feature 2 > 28.5)
#                If (feature 3 <= 2.5)
#                 If (feature 2 <= 31.5)
#                  Predict: 3.0
#                 Else (feature 2 > 31.5)
#                  Predict: 2.0
#                Else (feature 3 > 2.5)
#                 If (feature 1 <= 77.5)
#                  If (feature 1 <= 57.5)
#                   If (feature 1 <= 28.5)
#                    If (feature 1 <= 24.5)
#                     If (feature 3 <= 10.5)
#                      Predict: 4.0
#                     Else (feature 3 > 10.5)
#                      Predict: 3.0
#                    Else (feature 1 > 24.5)
#                     Predict: 3.0
#                   Else (feature 1 > 28.5)
#                    Predict: 4.0
#                  Else (feature 1 > 57.5)
#                   If (feature 3 <= 9.5)
#                    If (feature 1 <= 59.5)
#                     Predict: 2.0
#                    Else (feature 1 > 59.5)
#                     Predict: 4.0
#                   Else (feature 3 > 9.5)
#                    If (feature 2 <= 30.5)
#                     If (feature 1 <= 60.5)
#                      Predict: 3.0
#                     Else (feature 1 > 60.5)
#                      Predict: 4.0
#                    Else (feature 2 > 30.5)
#                     Predict: 3.0
#                 Else (feature 1 > 77.5)
#                  If (feature 2 <= 31.5)
#                   Predict: 4.0
#                  Else (feature 2 > 31.5)
#                   If (feature 2 <= 44.5)
#                    If (feature 3 <= 28.5)
#                     Predict: 2.0
#                    Else (feature 3 > 28.5)
#                     Predict: 4.0
#                   Else (feature 2 > 44.5)
#                    Predict: 4.0
#              Else (feature 2 > 52.5)
#               If (feature 1 <= 52.5)
#                If (feature 2 <= 53.5)
#                 If (feature 3 <= 13.5)
#                  Predict: 3.0
#                 Else (feature 3 > 13.5)
#                  If (feature 1 <= 4.5)
#                   Predict: 3.0
#                  Else (feature 1 > 4.5)
#                   If (feature 1 <= 6.5)
#                    If (feature 1 <= 5.5)
#                     Predict: 4.0
#                    Else (feature 1 > 5.5)
#                     Predict: 2.0
#                   Else (feature 1 > 6.5)
#                    Predict: 4.0
#                Else (feature 2 > 53.5)
#                 Predict: 3.0
#               Else (feature 1 > 52.5)
#                If (feature 3 <= 1.5)
#                 Predict: 3.0
#                Else (feature 3 > 1.5)
#                 If (feature 2 <= 53.5)
#                  Predict: 4.0
#                 Else (feature 2 > 53.5)
#                  If (feature 1 <= 136.5)
#                   Predict: 3.0
#                  Else (feature 1 > 136.5)
#                   Predict: 4.0
#             Else (feature 2 > 55.5)
#              If (feature 0 in {1.0})
#               If (feature 1 <= 110.5)
#                If (feature 2 <= 92.5)
#                 If (feature 2 <= 67.5)
#                  Predict: 4.0
#                 Else (feature 2 > 67.5)
#                  Predict: 3.0
#                Else (feature 2 > 92.5)
#                 If (feature 2 <= 98.5)
#                  Predict: 4.0
#                 Else (feature 2 > 98.5)
#                  If (feature 1 <= 90.5)
#                   Predict: 3.0
#                  Else (feature 1 > 90.5)
#                   Predict: 4.0
#               Else (feature 1 > 110.5)
#                If (feature 1 <= 115.5)
#                 Predict: 3.0
#                Else (feature 1 > 115.5)
#                 Predict: 2.0
#              Else (feature 0 not in {1.0})
#               If (feature 2 <= 101.5)
#                If (feature 2 <= 65.5)
#                 If (feature 2 <= 61.5)
#                  If (feature 1 <= 50.5)
#                   Predict: 4.0
#                  Else (feature 1 > 50.5)
#                   If (feature 1 <= 100.5)
#                    If (feature 3 <= 18.5)
#                     Predict: 2.0
#                    Else (feature 3 > 18.5)
#                     If (feature 2 <= 60.5)
#                      Predict: 2.0
#                     Else (feature 2 > 60.5)
#                      Predict: 3.0
#                   Else (feature 1 > 100.5)
#                    Predict: 4.0
#                 Else (feature 2 > 61.5)
#                  If (feature 3 <= 8.5)
#                   If (feature 1 <= 100.5)
#                    Predict: 3.0
#                   Else (feature 1 > 100.5)
#                    Predict: 4.0
#                  Else (feature 3 > 8.5)
#                   Predict: 4.0
#                Else (feature 2 > 65.5)
#                 Predict: 2.0
#               Else (feature 2 > 101.5)
#                If (feature 1 <= 139.5)
#                 If (feature 1 <= 77.5)
#                  Predict: 4.0
#                 Else (feature 1 > 77.5)
#                  If (feature 3 <= 22.5)
#                   If (feature 1 <= 119.5)
#                    If (feature 1 <= 90.5)
#                     Predict: 3.0
#                    Else (feature 1 > 90.5)
#                     If (feature 1 <= 92.5)
#                      Predict: 4.0
#                     Else (feature 1 > 92.5)
#                      Predict: 3.0
#                   Else (feature 1 > 119.5)
#                    Predict: 2.0
#                  Else (feature 3 > 22.5)
#                   Predict: 4.0
#                Else (feature 1 > 139.5)
#                 If (feature 3 <= 6.5)
#                  Predict: 2.0
#                 Else (feature 3 > 6.5)
#                  If (feature 1 <= 142.5)
#                   Predict: 3.0
#                  Else (feature 1 > 142.5)
#                   Predict: 4.0
#          Else (feature 4 > 3.5)
#           If (feature 0 in {1.0})
#            If (feature 2 <= 26.5)
#             If (feature 3 <= 19.5)
#              If (feature 2 <= 23.5)
#               If (feature 1 <= 76.5)
#                If (feature 2 <= 14.5)
#                 If (feature 4 <= 4.5)
#                  If (feature 2 <= 9.5)
#                   If (feature 1 <= 17.5)
#                    If (feature 1 <= 7.5)
#                     Predict: 3.0
#                    Else (feature 1 > 7.5)
#                     If (feature 3 <= 3.5)
#                      Predict: 3.0
#                     Else (feature 3 > 3.5)
#                      Predict: 2.0
#                   Else (feature 1 > 17.5)
#                    Predict: 3.0
#                  Else (feature 2 > 9.5)
#                   Predict: 1.0
#                 Else (feature 4 > 4.5)
#                  If (feature 3 <= 16.5)
#                   If (feature 1 <= 17.5)
#                    If (feature 1 <= 7.5)
#                     Predict: 4.0
#                    Else (feature 1 > 7.5)
#                     Predict: 1.0
#                   Else (feature 1 > 17.5)
#                    If (feature 3 <= 7.5)
#                     If (feature 3 <= 3.5)
#                      If (feature 1 <= 39.5)
#                       Predict: 3.0
#                      Else (feature 1 > 39.5)
#                       Predict: 1.0
#                     Else (feature 3 > 3.5)
#                      If (feature 1 <= 72.5)
#                       Predict: 2.0
#                      Else (feature 1 > 72.5)
#                       Predict: 3.0
#                    Else (feature 3 > 7.5)
#                     If (feature 2 <= 8.5)
#                      If (feature 1 <= 29.5)
#                       Predict: 2.0
#                      Else (feature 1 > 29.5)
#                       Predict: 4.0
#                     Else (feature 2 > 8.5)
#                      Predict: 3.0
#                  Else (feature 3 > 16.5)
#                   Predict: 2.0
#                Else (feature 2 > 14.5)
#                 If (feature 3 <= 3.5)
#                  If (feature 1 <= 9.5)
#                   Predict: 4.0
#                  Else (feature 1 > 9.5)
#                   Predict: 3.0
#                 Else (feature 3 > 3.5)
#                  If (feature 1 <= 27.5)
#                   Predict: 3.0
#                  Else (feature 1 > 27.5)
#                   If (feature 1 <= 32.5)
#                    If (feature 4 <= 4.5)
#                     Predict: 2.0
#                    Else (feature 4 > 4.5)
#                     Predict: 3.0
#                   Else (feature 1 > 32.5)
#                    If (feature 1 <= 44.5)
#                     If (feature 1 <= 41.5)
#                      Predict: 3.0
#                     Else (feature 1 > 41.5)
#                      Predict: 2.0
#                    Else (feature 1 > 44.5)
#                     Predict: 3.0
#               Else (feature 1 > 76.5)
#                If (feature 4 <= 4.5)
#                 Predict: 2.0
#                Else (feature 4 > 4.5)
#                 If (feature 2 <= 20.5)
#                  Predict: 2.0
#                 Else (feature 2 > 20.5)
#                  If (feature 1 <= 86.5)
#                   Predict: 1.0
#                  Else (feature 1 > 86.5)
#                   If (feature 3 <= 2.5)
#                    Predict: 1.0
#                   Else (feature 3 > 2.5)
#                    If (feature 3 <= 6.5)
#                     If (feature 1 <= 125.5)
#                      Predict: 1.0
#                     Else (feature 1 > 125.5)
#                      Predict: 3.0
#                    Else (feature 3 > 6.5)
#                     Predict: 3.0
#              Else (feature 2 > 23.5)
#               If (feature 4 <= 4.5)
#                Predict: 4.0
#               Else (feature 4 > 4.5)
#                If (feature 1 <= 55.5)
#                 Predict: 4.0
#                Else (feature 1 > 55.5)
#                 Predict: 3.0
#             Else (feature 3 > 19.5)
#              If (feature 2 <= 15.5)
#               If (feature 3 <= 26.5)
#                If (feature 1 <= 10.5)
#                 Predict: 3.0
#                Else (feature 1 > 10.5)
#                 If (feature 3 <= 24.5)
#                  If (feature 2 <= 14.5)
#                   If (feature 3 <= 22.5)
#                    Predict: 1.0
#                   Else (feature 3 > 22.5)
#                    If (feature 1 <= 28.5)
#                     If (feature 1 <= 23.5)
#                      Predict: 1.0
#                     Else (feature 1 > 23.5)
#                      Predict: 2.0
#                    Else (feature 1 > 28.5)
#                     Predict: 1.0
#                  Else (feature 2 > 14.5)
#                   Predict: 3.0
#                 Else (feature 3 > 24.5)
#                  If (feature 1 <= 38.5)
#                   Predict: 2.0
#                  Else (feature 1 > 38.5)
#                   If (feature 4 <= 4.5)
#                    Predict: 1.0
#                   Else (feature 4 > 4.5)
#                    Predict: 3.0
#               Else (feature 3 > 26.5)
#                If (feature 2 <= 5.5)
#                 If (feature 4 <= 4.5)
#                  Predict: 1.0
#                 Else (feature 4 > 4.5)
#                  If (feature 1 <= 36.5)
#                   Predict: 1.0
#                  Else (feature 1 > 36.5)
#                   Predict: 3.0
#                Else (feature 2 > 5.5)
#                 If (feature 1 <= 3.5)
#                  If (feature 1 <= 2.5)
#                   Predict: 1.0
#                  Else (feature 1 > 2.5)
#                   Predict: 3.0
#                 Else (feature 1 > 3.5)
#                  If (feature 3 <= 27.5)
#                   If (feature 1 <= 76.5)
#                    Predict: 1.0
#                   Else (feature 1 > 76.5)
#                    If (feature 4 <= 4.5)
#                     Predict: 1.0
#                    Else (feature 4 > 4.5)
#                     Predict: 3.0
#                  Else (feature 3 > 27.5)
#                   If (feature 3 <= 33.5)
#                    If (feature 2 <= 8.5)
#                     If (feature 1 <= 6.5)
#                      Predict: 1.0
#                     Else (feature 1 > 6.5)
#                      Predict: 4.0
#                    Else (feature 2 > 8.5)
#                     Predict: 1.0
#                   Else (feature 3 > 33.5)
#                    If (feature 1 <= 90.5)
#                     Predict: 1.0
#                    Else (feature 1 > 90.5)
#                     If (feature 4 <= 4.5)
#                      Predict: 4.0
#                     Else (feature 4 > 4.5)
#                      Predict: 1.0
#              Else (feature 2 > 15.5)
#               If (feature 2 <= 20.5)
#                If (feature 4 <= 4.5)
#                 If (feature 1 <= 30.5)
#                  If (feature 1 <= 26.5)
#                   Predict: 3.0
#                  Else (feature 1 > 26.5)
#                   Predict: 4.0
#                 Else (feature 1 > 30.5)
#                  Predict: 3.0
#                Else (feature 4 > 4.5)
#                 Predict: 2.0
#               Else (feature 2 > 20.5)
#                If (feature 2 <= 23.5)
#                 If (feature 4 <= 4.5)
#                  Predict: 2.0
#                 Else (feature 4 > 4.5)
#                  If (feature 1 <= 54.5)
#                   If (feature 1 <= 51.5)
#                    Predict: 1.0
#                   Else (feature 1 > 51.5)
#                    Predict: 3.0
#                  Else (feature 1 > 54.5)
#                   Predict: 1.0
#                Else (feature 2 > 23.5)
#                 If (feature 3 <= 27.5)
#                  If (feature 3 <= 22.5)
#                   If (feature 3 <= 20.5)
#                    If (feature 4 <= 4.5)
#                     Predict: 1.0
#                    Else (feature 4 > 4.5)
#                     Predict: 3.0
#                   Else (feature 3 > 20.5)
#                    Predict: 4.0
#                  Else (feature 3 > 22.5)
#                   Predict: 1.0
#                 Else (feature 3 > 27.5)
#                  Predict: 4.0
#            Else (feature 2 > 26.5)
#             If (feature 3 <= 26.5)
#              If (feature 2 <= 59.5)
#               If (feature 3 <= 8.5)
#                If (feature 1 <= 3.5)
#                 Predict: 4.0
#                Else (feature 1 > 3.5)
#                 If (feature 2 <= 47.5)
#                  If (feature 3 <= 2.5)
#                   Predict: 1.0
#                  Else (feature 3 > 2.5)
#                   If (feature 1 <= 22.5)
#                    Predict: 1.0
#                   Else (feature 1 > 22.5)
#                    Predict: 2.0
#                 Else (feature 2 > 47.5)
#                  Predict: 1.0
#               Else (feature 3 > 8.5)
#                If (feature 1 <= 123.5)
#                 Predict: 1.0
#                Else (feature 1 > 123.5)
#                 If (feature 4 <= 4.5)
#                  Predict: 1.0
#                 Else (feature 4 > 4.5)
#                  If (feature 3 <= 18.5)
#                   Predict: 1.0
#                  Else (feature 3 > 18.5)
#                   Predict: 3.0
#              Else (feature 2 > 59.5)
#               If (feature 2 <= 92.5)
#                If (feature 4 <= 4.5)
#                 If (feature 3 <= 13.5)
#                  If (feature 1 <= 16.5)
#                   Predict: 4.0
#                  Else (feature 1 > 16.5)
#                   Predict: 3.0
#                 Else (feature 3 > 13.5)
#                  Predict: 3.0
#                Else (feature 4 > 4.5)
#                 If (feature 3 <= 2.5)
#                  Predict: 4.0
#                 Else (feature 3 > 2.5)
#                  If (feature 1 <= 14.5)
#                   Predict: 2.0
#                  Else (feature 1 > 14.5)
#                   Predict: 1.0
#               Else (feature 2 > 92.5)
#                If (feature 2 <= 160.5)
#                 If (feature 3 <= 13.5)
#                  If (feature 1 <= 66.5)
#                   Predict: 1.0
#                  Else (feature 1 > 66.5)
#                   If (feature 1 <= 127.5)
#                    If (feature 2 <= 130.5)
#                     If (feature 3 <= 3.5)
#                      If (feature 4 <= 4.5)
#                       Predict: 3.0
# ...
#                 If (feature 1 <= 53.5)
#                  Predict: 2.0
#                 Else (feature 1 > 53.5)
#                  If (feature 1 <= 74.5)
#                   Predict: 4.0
#                  Else (feature 1 > 74.5)
#                   If (feature 1 <= 76.5)
#                    Predict: 1.0
#                   Else (feature 1 > 76.5)
#                    Predict: 2.0
#               Else (feature 3 > 11.5)
#                Predict: 1.0
#              Else (feature 2 > 111.5)
#               If (feature 4 <= 234.5)
#                If (feature 4 <= 182.5)
#                 If (feature 1 <= 81.5)
#                  Predict: 2.0
#                 Else (feature 1 > 81.5)
#                  Predict: 4.0
#                Else (feature 4 > 182.5)
#                 If (feature 1 <= 77.5)
#                  Predict: 2.0
#                 Else (feature 1 > 77.5)
#                  If (feature 2 <= 123.5)
#                   If (feature 4 <= 194.5)
#                    If (feature 1 <= 108.5)
#                     Predict: 1.0
#                    Else (feature 1 > 108.5)
#                     Predict: 3.0
#                   Else (feature 4 > 194.5)
#                    Predict: 1.0
#                  Else (feature 2 > 123.5)
#                   If (feature 1 <= 95.5)
#                    Predict: 1.0
#                   Else (feature 1 > 95.5)
#                    Predict: 2.0
#               Else (feature 4 > 234.5)
#                If (feature 2 <= 114.5)
#                 If (feature 4 <= 270.5)
#                  If (feature 1 <= 114.5)
#                   If (feature 3 <= 11.5)
#                    Predict: 3.0
#                   Else (feature 3 > 11.5)
#                    If (feature 4 <= 249.5)
#                     Predict: 3.0
#                    Else (feature 4 > 249.5)
#                     Predict: 4.0
#                  Else (feature 1 > 114.5)
#                   If (feature 1 <= 119.5)
#                    Predict: 2.0
#                   Else (feature 1 > 119.5)
#                    Predict: 3.0
#                 Else (feature 4 > 270.5)
#                  If (feature 4 <= 294.5)
#                   Predict: 1.0
#                  Else (feature 4 > 294.5)
#                   If (feature 3 <= 8.5)
#                    If (feature 1 <= 77.5)
#                     Predict: 1.0
#                    Else (feature 1 > 77.5)
#                     If (feature 3 <= 6.5)
#                      If (feature 4 <= 352.5)
#                       Predict: 3.0
#                      Else (feature 4 > 352.5)
#                       Predict: 4.0
#                     Else (feature 3 > 6.5)
#                      Predict: 4.0
#                   Else (feature 3 > 8.5)
#                    If (feature 4 <= 352.5)
#                     Predict: 2.0
#                    Else (feature 4 > 352.5)
#                     If (feature 1 <= 63.5)
#                      Predict: 4.0
#                     Else (feature 1 > 63.5)
#                      If (feature 2 <= 112.5)
#                       Predict: 2.0
#                      Else (feature 2 > 112.5)
#                       Predict: 1.0
#                Else (feature 2 > 114.5)
#                 If (feature 1 <= 108.5)
#                  If (feature 1 <= 81.5)
#                   Predict: 1.0
#                  Else (feature 1 > 81.5)
#                   If (feature 4 <= 249.5)
#                    If (feature 1 <= 90.5)
#                     If (feature 1 <= 83.5)
#                      Predict: 2.0
#                     Else (feature 1 > 83.5)
#                      Predict: 1.0
#                    Else (feature 1 > 90.5)
#                     Predict: 2.0
#                   Else (feature 4 > 249.5)
#                    Predict: 1.0
#                 Else (feature 1 > 108.5)
#                  Predict: 4.0
#           Else (feature 3 > 12.5)
#            If (feature 2 <= 114.5)
#             If (feature 2 <= 111.5)
#              If (feature 4 <= 234.5)
#               If (feature 4 <= 219.5)
#                If (feature 1 <= 30.5)
#                 Predict: 3.0
#                Else (feature 1 > 30.5)
#                 If (feature 3 <= 24.5)
#                  If (feature 2 <= 69.5)
#                   If (feature 1 <= 111.5)
#                    Predict: 1.0
#                   Else (feature 1 > 111.5)
#                    Predict: 3.0
#                  Else (feature 2 > 69.5)
#                   If (feature 3 <= 20.5)
#                    If (feature 2 <= 103.5)
#                     If (feature 3 <= 13.5)
#                      Predict: 1.0
#                     Else (feature 3 > 13.5)
#                      Predict: 2.0
#                    Else (feature 2 > 103.5)
#                     Predict: 1.0
#                   Else (feature 3 > 20.5)
#                    Predict: 1.0
#                 Else (feature 3 > 24.5)
#                  If (feature 1 <= 50.5)
#                   Predict: 2.0
#                  Else (feature 1 > 50.5)
#                   If (feature 4 <= 194.5)
#                    Predict: 3.0
#                   Else (feature 4 > 194.5)
#                    Predict: 2.0
#               Else (feature 4 > 219.5)
#                If (feature 1 <= 28.5)
#                 Predict: 4.0
#                Else (feature 1 > 28.5)
#                 Predict: 1.0
#              Else (feature 4 > 234.5)
#               If (feature 4 <= 404.5)
#                If (feature 3 <= 13.5)
#                 If (feature 1 <= 87.5)
#                  Predict: 1.0
#                 Else (feature 1 > 87.5)
#                  Predict: 3.0
#                Else (feature 3 > 13.5)
#                 If (feature 1 <= 148.5)
#                  If (feature 4 <= 319.5)
#                   If (feature 1 <= 28.5)
#                    Predict: 1.0
#                   Else (feature 1 > 28.5)
#                    If (feature 4 <= 249.5)
#                     If (feature 1 <= 71.5)
#                      Predict: 1.0
#                     Else (feature 1 > 71.5)
#                      If (feature 3 <= 16.5)
#                       Predict: 2.0
#                      Else (feature 3 > 16.5)
#                       Predict: 3.0
#                    Else (feature 4 > 249.5)
#                     If (feature 2 <= 86.5)
#                      Predict: 3.0
#                     Else (feature 2 > 86.5)
#                      If (feature 2 <= 89.5)
#                       Predict: 4.0
#                      Else (feature 2 > 89.5)
#                       Predict: 3.0
#                  Else (feature 4 > 319.5)
#                   If (feature 2 <= 97.5)
#                    If (feature 1 <= 102.5)
#                     If (feature 1 <= 28.5)
#                      If (feature 1 <= 24.5)
#                       Predict: 2.0
#                      Else (feature 1 > 24.5)
#                       Predict: 3.0
#                     Else (feature 1 > 28.5)
#                      If (feature 2 <= 86.5)
#                       Predict: 4.0
#                      Else (feature 2 > 86.5)
#                       Predict: 3.0
#                    Else (feature 1 > 102.5)
#                     Predict: 3.0
#                   Else (feature 2 > 97.5)
#                    Predict: 2.0
#                 Else (feature 1 > 148.5)
#                  Predict: 4.0
#               Else (feature 4 > 404.5)
#                If (feature 2 <= 73.5)
#                 If (feature 1 <= 46.5)
#                  Predict: 2.0
#                 Else (feature 1 > 46.5)
#                  Predict: 1.0
#                Else (feature 2 > 73.5)
#                 If (feature 2 <= 86.5)
#                  If (feature 1 <= 36.5)
#                   Predict: 1.0
#                  Else (feature 1 > 36.5)
#                   Predict: 4.0
#                 Else (feature 2 > 86.5)
#                  Predict: 2.0
#             Else (feature 2 > 111.5)
#              If (feature 4 <= 249.5)
#               If (feature 1 <= 98.5)
#                Predict: 3.0
#               Else (feature 1 > 98.5)
#                Predict: 4.0
#              Else (feature 4 > 249.5)
#               If (feature 1 <= 93.5)
#                If (feature 1 <= 45.5)
#                 If (feature 4 <= 352.5)
#                  Predict: 1.0
#                 Else (feature 4 > 352.5)
#                  Predict: 3.0
#                Else (feature 1 > 45.5)
#                 Predict: 1.0
#               Else (feature 1 > 93.5)
#                If (feature 4 <= 270.5)
#                 Predict: 4.0
#                Else (feature 4 > 270.5)
#                 If (feature 1 <= 94.5)
#                  If (feature 4 <= 352.5)
#                   Predict: 3.0
#                  Else (feature 4 > 352.5)
#                   Predict: 4.0
#                 Else (feature 1 > 94.5)
#                  Predict: 3.0
#            Else (feature 2 > 114.5)
#             If (feature 1 <= 133.5)
#              If (feature 3 <= 13.5)
#               If (feature 1 <= 63.5)
#                Predict: 1.0
#               Else (feature 1 > 63.5)
#                Predict: 4.0
#              Else (feature 3 > 13.5)
#               If (feature 3 <= 20.5)
#                If (feature 1 <= 77.5)
#                 Predict: 2.0
#                Else (feature 1 > 77.5)
#                 Predict: 3.0
#               Else (feature 3 > 20.5)
#                If (feature 4 <= 294.5)
#                 If (feature 1 <= 66.5)
#                  If (feature 1 <= 47.5)
#                   If (feature 3 <= 25.5)
#                    If (feature 1 <= 35.5)
#                     Predict: 2.0
#                    Else (feature 1 > 35.5)
#                     Predict: 3.0
#                   Else (feature 3 > 25.5)
#                    Predict: 2.0
#                  Else (feature 1 > 47.5)
#                   If (feature 3 <= 21.5)
#                    Predict: 2.0
#                   Else (feature 3 > 21.5)
#                    Predict: 3.0
#                 Else (feature 1 > 66.5)
#                  Predict: 2.0
#                Else (feature 4 > 294.5)
#                 If (feature 2 <= 123.5)
#                  Predict: 1.0
#                 Else (feature 2 > 123.5)
#                  Predict: 3.0
#             Else (feature 1 > 133.5)
#              Predict: 2.0
#       Else (feature 2 > 140.5)
#        If (feature 4 <= 352.5)
#         If (feature 4 <= 182.5)
#          If (feature 4 <= 134.5)
#           If (feature 3 <= 12.5)
#            If (feature 1 <= 136.5)
#             If (feature 2 <= 181.5)
#              If (feature 1 <= 68.5)
#               Predict: 1.0
#              Else (feature 1 > 68.5)
#               Predict: 2.0
#             Else (feature 2 > 181.5)
#              Predict: 1.0
#            Else (feature 1 > 136.5)
#             Predict: 1.0
#           Else (feature 3 > 12.5)
#            If (feature 2 <= 157.5)
#             If (feature 3 <= 16.5)
#              Predict: 1.0
#             Else (feature 3 > 16.5)
#              Predict: 2.0
#            Else (feature 2 > 157.5)
#             Predict: 4.0
#          Else (feature 4 > 134.5)
#           If (feature 1 <= 14.5)
#            If (feature 4 <= 141.5)
#             Predict: 4.0
#            Else (feature 4 > 141.5)
#             Predict: 2.0
#           Else (feature 1 > 14.5)
#            If (feature 3 <= 20.5)
#             If (feature 1 <= 136.5)
#              If (feature 1 <= 50.5)
#               Predict: 3.0
#              Else (feature 1 > 50.5)
#               If (feature 3 <= 3.5)
#                If (feature 1 <= 105.5)
#                 If (feature 1 <= 91.5)
#                  Predict: 4.0
#                 Else (feature 1 > 91.5)
#                  Predict: 3.0
#                Else (feature 1 > 105.5)
#                 If (feature 1 <= 112.5)
#                  Predict: 2.0
#                 Else (feature 1 > 112.5)
#                  Predict: 3.0
#               Else (feature 3 > 3.5)
#                If (feature 4 <= 163.5)
#                 If (feature 2 <= 181.5)
#                  Predict: 2.0
#                 Else (feature 2 > 181.5)
#                  Predict: 4.0
#                Else (feature 4 > 163.5)
#                 If (feature 2 <= 181.5)
#                  Predict: 1.0
#                 Else (feature 2 > 181.5)
#                  Predict: 2.0
#             Else (feature 1 > 136.5)
#              If (feature 2 <= 176.5)
#               If (feature 4 <= 141.5)
#                Predict: 3.0
#               Else (feature 4 > 141.5)
#                Predict: 1.0
#              Else (feature 2 > 176.5)
#               Predict: 1.0
#            Else (feature 3 > 20.5)
#             If (feature 1 <= 39.5)
#              Predict: 1.0
#             Else (feature 1 > 39.5)
#              If (feature 3 <= 33.5)
#               Predict: 3.0
#              Else (feature 3 > 33.5)
#               If (feature 4 <= 141.5)
#                Predict: 1.0
#               Else (feature 4 > 141.5)
#                Predict: 3.0
#         Else (feature 4 > 182.5)
#          If (feature 4 <= 207.5)
#           If (feature 2 <= 176.5)
#            Predict: 1.0
#           Else (feature 2 > 176.5)
#            If (feature 1 <= 0.5)
#             Predict: 4.0
#            Else (feature 1 > 0.5)
#             Predict: 2.0
#          Else (feature 4 > 207.5)
#           If (feature 4 <= 319.5)
#            If (feature 1 <= 1.5)
#             Predict: 2.0
#            Else (feature 1 > 1.5)
#             If (feature 1 <= 147.5)
#              If (feature 4 <= 219.5)
#               If (feature 1 <= 64.5)
#                If (feature 1 <= 9.5)
#                 Predict: 1.0
#                Else (feature 1 > 9.5)
#                 If (feature 1 <= 35.5)
#                  Predict: 2.0
#                 Else (feature 1 > 35.5)
#                  Predict: 1.0
#               Else (feature 1 > 64.5)
#                Predict: 4.0
#              Else (feature 4 > 219.5)
#               If (feature 2 <= 172.5)
#                If (feature 1 <= 103.5)
#                 If (feature 1 <= 13.5)
#                  If (feature 4 <= 249.5)
#                   Predict: 1.0
#                  Else (feature 4 > 249.5)
#                   If (feature 1 <= 7.5)
#                    Predict: 1.0
#                   Else (feature 1 > 7.5)
#                    Predict: 3.0
#                 Else (feature 1 > 13.5)
#                  Predict: 3.0
#                Else (feature 1 > 103.5)
#                 Predict: 4.0
#               Else (feature 2 > 172.5)
#                If (feature 3 <= 4.5)
#                 If (feature 1 <= 134.5)
#                  If (feature 4 <= 234.5)
#                   Predict: 3.0
#                  Else (feature 4 > 234.5)
#                   If (feature 1 <= 35.5)
#                    If (feature 4 <= 249.5)
#                     Predict: 2.0
#                    Else (feature 4 > 249.5)
#                     Predict: 1.0
#                   Else (feature 1 > 35.5)
#                    If (feature 4 <= 249.5)
#                     Predict: 3.0
#                    Else (feature 4 > 249.5)
#                     Predict: 2.0
#                 Else (feature 1 > 134.5)
#                  Predict: 1.0
#                Else (feature 3 > 4.5)
#                 Predict: 1.0
#             Else (feature 1 > 147.5)
#              Predict: 2.0
#           Else (feature 4 > 319.5)
#            If (feature 3 <= 2.5)
#             Predict: 2.0
#            Else (feature 3 > 2.5)
#             Predict: 1.0
#        Else (feature 4 > 352.5)
#         If (feature 1 <= 64.5)
#          If (feature 3 <= 20.5)
#           If (feature 1 <= 45.5)
#            Predict: 2.0
#           Else (feature 1 > 45.5)
#            Predict: 3.0
#          Else (feature 3 > 20.5)
#           If (feature 4 <= 404.5)
#            If (feature 1 <= 7.5)
#             Predict: 2.0
#            Else (feature 1 > 7.5)
#             Predict: 1.0
#           Else (feature 4 > 404.5)
#            If (feature 1 <= 16.5)
#             If (feature 1 <= 13.5)
#              If (feature 1 <= 7.5)
#               Predict: 3.0
#              Else (feature 1 > 7.5)
#               Predict: 2.0
#             Else (feature 1 > 13.5)
#              Predict: 3.0
#            Else (feature 1 > 16.5)
#             Predict: 1.0
#         Else (feature 1 > 64.5)
#          If (feature 1 <= 90.5)
#           Predict: 1.0
#          Else (feature 1 > 90.5)
#           If (feature 1 <= 130.5)
#            If (feature 1 <= 105.5)
#             If (feature 2 <= 172.5)
#              If (feature 4 <= 404.5)
#               Predict: 1.0
#              Else (feature 4 > 404.5)
#               Predict: 3.0
#             Else (feature 2 > 172.5)
#              Predict: 3.0
#            Else (feature 1 > 105.5)
#             Predict: 1.0
#           Else (feature 1 > 130.5)
#            Predict: 3.0

# %%
from pyspark.mllib.evaluation import MulticlassMetrics

metrics = MulticlassMetrics(predictionAndLabel)

# Overall statistics
precision = metrics.precision()
recall = metrics.recall()
f1Score = metrics.fMeasure()
print("Summary Stats")
print("Precision = %s" % precision)
print("Recall = %s" % recall)
print("F1 Score = %s" % f1Score)

# Statistics by class
labels = df2.map(lambda lp: lp.label).distinct().collect()
for label in sorted(labels):
    print("Class %s precision = %s" % (label, metrics.precision(label)))
    print("Class %s recall = %s" % (label, metrics.recall(label)))
    print("Class %s F1 Measure = %s" % (label, metrics.fMeasure(label, beta=1.0)))
# Out:
# Summary Stats
# Precision = 0.6388782626607421
# Recall = 0.6388782626607421
# F1 Score = 0.6388782626607421
# Class 1.0 precision = 0.643773010029199
# Class 1.0 recall = 0.6041219918989754
# Class 1.0 F1 Measure = 0.6233175588470284
# Class 2.0 precision = 0.6609347845970914
# Class 2.0 recall = 0.6529321405981747
# Class 2.0 F1 Measure = 0.6569090909090909
# Class 3.0 precision = 0.6476510067114094
# Class 3.0 recall = 0.6599316133043208
# Class 3.0 F1 Measure = 0.6537336412625095
# Class 4.0 precision = 0.5703315227570707
# Class 4.0 recall = 0.6251283104085403
# Class 4.0 F1 Measure = 0.5964740450538688
